# %%
##Lectura de archivos


import pandas as pd
import matplotlib.pyplot as plt
#-----Matematicas y quimica-------
archivo_matematicas = '/Users/janeth/Documents/ASISTENCIA GEA MATEMÁTICAS Y QUÍMICA 2024-2S.xlsx'
#------Lectoescritura e ingles-----
archivo_lecto = '/Users/janeth/Documents/ASISTENCIA GEA LECTOESCRITURA E INGLÉS 2024-2S.xlsx'

#-----Matematicas-----
df_mate = pd.read_excel(archivo_matematicas, sheet_name='Matemáticas')
conteo_tutores_mate = df_mate['Tutor'].value_counts()
df_mate = df_mate[df_mate['Identificación '].notna()]

#----Quimica---
df_quimica = pd.read_excel(archivo_matematicas, sheet_name='Química')
conteo_tutores_quimica = df_quimica['Tutor'].value_counts()
df_quimica = df_quimica[df_quimica['Identificación '].notna()]

#----Lectoescritura---
df_lecto = pd.read_excel(archivo_lecto, sheet_name='Lectoescritura')
conteo_tutores_lecto = df_lecto['Tutor'].value_counts()
df_lecto = df_lecto[df_lecto['Identificación '].notna()]

#----Inglés---
df_ingles = pd.read_excel(archivo_lecto, sheet_name='Inglés')
conteo_tutores_lecto = df_ingles['Tutor'].value_counts()
df_ingles = df_ingles[df_ingles['Identificación '].notna()]

#----- Total----

df_all=pd.concat([df_ingles, df_lecto,df_quimica, df_mate ], ignore_index=True)
df_all.head()
# Out:
# /Users/janeth/Library/Python/3.9/lib/python/site-packages/openpyxl/worksheet/_reader.py:329: UserWarning: Data Validation extension is not supported and will be removed
#   warn(msg)
# /Users/janeth/Library/Python/3.9/lib/python/site-packages/openpyxl/worksheet/_reader.py:329: UserWarning: Data Validation extension is not supported and will be removed
#   warn(msg)
# /Users/janeth/Library/Python/3.9/lib/python/site-packages/openpyxl/worksheet/_reader.py:329: UserWarning: Data Validation extension is not supported and will be removed
#   warn(msg)
# /Users/janeth/Library/Python/3.9/lib/python/site-packages/openpyxl/worksheet/_reader.py:329: UserWarning: Data Validation extension is not supported and will be removed
#   warn(msg)
#    # Fecha : Recordar (DD/MM/AAAA) Jornada  Identificación   \
# 0  1                    2024-11-21  Mañana     1.010082e+09
# 1  2                    2024-11-21  Mañana     1.120216e+09
# 2  3                    2024-11-22  Mañana     1.087787e+09
# 3  4                    2024-11-22  Mañana     1.004691e+09
# 4  5                    2024-11-22  Mañana     1.087786e+09
#
#         Correo institucional                         Nombre completo  \
# 0      mrojasria@unal.edu.co             María Del Mar Rojas Riascos
# 1  lbuesaquilloj@unal.edu.co  Luis Alejandro Buesaquillo Jacanamejoy
# 2    sestupinane@unal.edu.co     Sebastián Darío Estupiñán Estupiñán
# 3     mportillaa@unal.edu.co             Marlon Jair Portilla Araujo
# 4         ntello@unal.edu.co                    Nasly Tello Valencia
#
#      Programa curricular         Tutor      Asignatura  \
# 0  Nutrición y dietética  Luisana Paez       Inglés II
# 1           Antropología  Luisana Paez  Lectoescritura
# 2  Ingeniería industrial  Luisana Paez       Inglés II
# 3               Geología  Luisana Paez       Inglés II
# 4  Ingeniería agronómica  Luisana Paez       Inglés II
#
#        Motivo de la consulta  ... Tutor.1 Asignatura.1  \
# 0  Estudiar para una entrega  ...     NaN          NaN
# 1           Estudio autónomo  ...     NaN          NaN
# 2  Estudiar para una entrega  ...     NaN          NaN
# 3  Estudiar para una entrega  ...     NaN          NaN
# 4  Estudiar para una entrega  ...     NaN          NaN
#
#    Motivo de la consulta  Medio de comunicación.1  Semana Académica     Mes.1  \
# 0                     NaN                     NaN               1.0  Febrero
# 1                     NaN                     NaN               3.0    Abril
# 2                     NaN                     NaN               4.0     Mayo
# 3                     NaN                     NaN               5.0    Junio
# 4                     NaN                     NaN               6.0    Julio
#
#    Dia de la Semana   Unnamed: 23  Unnamed: 24  \
# 0             Lunes           NaN          NaN
# 1             Martes          NaN          NaN
# 2          Miércoles          NaN          NaN
# 3             Jueves          NaN          NaN
# 4            Viernes          NaN          NaN
#
#                   NOMBRES_APELLIDOS
# 0                   Reyes Sevillano
# 1     Adrian Fabricio Ceron Burbano
# 2          Adriana  Sevillano Deusa
# 3    Adriana Patricia Torres Angulo
# 4  Aida Alexandra Rodriguez Gongora
#
# [5 rows x 26 columns]

# %%
###Total asistencias



asistencias_mate = len(df_mate)
asistencias_quimica = len(df_quimica)
asistencias_lecto = len(df_lecto)
asistencias_ingles = len(df_ingles)

total_asistencias = asistencias_mate + asistencias_quimica + asistencias_lecto + asistencias_ingles
#----------------------------------------------------------
porcentaje_mate = (asistencias_mate / total_asistencias) * 100
porcentaje_quimica = (asistencias_quimica / total_asistencias) * 100
porcentaje_lecto = (asistencias_lecto / total_asistencias) * 100
porcentaje_ingles = (asistencias_ingles / total_asistencias) * 100
#-----------------------------------------------------------------------
asistencias_reales_mate = df_mate['Identificación '].nunique()
asistencias_reales_quimica = df_quimica['Identificación '].nunique()
asistencias_reales_lecto = df_lecto['Identificación '].nunique()
asistencias_reales_ingles = df_ingles['Identificación '].nunique()
#-----------------------------------------
df_combined = pd.concat([df_mate, df_quimica, df_lecto, df_ingles])
total_real = df_combined['Identificación '].nunique()

#---------------------------------------------------------------------------
data = {
    'Asignatura': ['Matemáticas', 'Lectoescritura', 'Inglés', 'Química'],
    'Asistencias': [asistencias_mate, asistencias_lecto, asistencias_ingles, asistencias_quimica],
    '% Asistencias': [porcentaje_mate, porcentaje_lecto, porcentaje_ingles, porcentaje_quimica]
}

df_resultados = pd.DataFrame(data)
df_resultados['Asistencias reales'] = [asistencias_reales_mate, asistencias_reales_lecto, asistencias_reales_ingles, asistencias_reales_quimica]
df_resultados['%Asistencias en el semestre'] = df_resultados['Asistencias'] / total_asistencias * 100

total = {
    'Asignatura': 'Total',
    'Asistencias': total_asistencias,
    '% Asistencias': 100,
    'Asistencias reales': total_real,
    '%Asistencias en el semestre': (df_resultados['Asistencias reales'].sum() / total_asistencias) * 100
}

df_total = pd.DataFrame([total])
df_resultados = pd.concat([df_resultados, df_total], ignore_index=True)
output_path = '/Users/janeth/Documents/Estadisticas/resultados_asistencias.xlsx'
df_resultados.to_excel(output_path, index=False)
df_resultados
# Out:
#        Asignatura  Asistencias  % Asistencias  Asistencias reales  \
# 0     Matemáticas          689      44.827586                 181
# 1  Lectoescritura          516      33.571893                 161
# 2          Inglés          194      12.621991                  66
# 3         Química          138       8.978530                  61
# 4           Total         1537     100.000000                 280
#
#    %Asistencias en el semestre
# 0                    44.827586
# 1                    33.571893
# 2                    12.621991
# 3                     8.978530
# 4                    30.513988

# %%
#  asistencias y porcentajes por asignatura
def calcular_asistencias_por_asignatura(df):
    asistencias_por_asignatura = df['Asignatura'].value_counts()
    total_asistencias_asignaturas = asistencias_por_asignatura.sum()
    porcentaje_asistencias = (asistencias_por_asignatura / total_asistencias_asignaturas) * 100
    reales=  df.groupby('Asignatura')['Identificación '].nunique()
    df_asistencias_asignaturas = pd.DataFrame({        'Asignatura': asistencias_por_asignatura.index,
        'Asistencias': asistencias_por_asignatura.values,
        '% Asistencias': porcentaje_asistencias.values,
        'Asistencias reales':reales.reindex(asistencias_por_asignatura.index).values
    
    })
    
    return df_asistencias_asignaturas.reset_index(drop=True)

df_asistencias_mate = calcular_asistencias_por_asignatura(df_mate)
df_asistencias_quimica = calcular_asistencias_por_asignatura(df_quimica)
df_asistencias_lecto = calcular_asistencias_por_asignatura(df_lecto)
df_asistencias_ingles = calcular_asistencias_por_asignatura(df_ingles)

print("Asistencias por asignatura (Matemáticas):")
display(df_asistencias_mate)

print("Asistencias por asignatura (Química):")
display(df_asistencias_quimica)

print("Asistencias por asignatura (Lectoescritura):")
display(df_asistencias_lecto)

print("Asistencias por asignatura (Inglés):")
display(df_asistencias_ingles)

df_asistencias_mate.to_excel('/Users/janeth/Documents/Estadisticas/asistenciamate.xlsx', index=False)
df_asistencias_quimica.to_excel('/Users/janeth/Documents/Estadisticas/asistenciaquimica.xlsx', index=False)
df_asistencias_lecto.to_excel('/Users/janeth/Documents/Estadisticas/asistencialecto.xlsx', index=False)
df_asistencias_ingles.to_excel('/Users/janeth/Documents/Estadisticas/asistenciaingles.xlsx', index=False)
# Out:
# Asistencias por asignatura (Matemáticas):
#                         Asignatura  Asistencias  % Asistencias  \
# 0                      Matemáticas          407      59.071118
# 1              Cálculo Diferencial          118      17.126270
# 2                 Cálculo Integral           73      10.595065
# 3                   Álgebra lineal           38       5.515239
# 4     Programacion de computadores           36       5.224964
# 5  Geometría Vectorial y analítica            9       1.306241
# 6           Física (Fund.Mecánica)            8       1.161103
#
#    Asistencias reales
# 0                 120
# 1                  39
# 2                  15
# 3                  16
# 4                  14
# 5                   5
# 6                   1
# Asistencias por asignatura (Química):
#          Asignatura  Asistencias  % Asistencias  Asistencias reales
# 0   Química General           95      68.840580                  52
# 1        Bioquímica           34      24.637681                   6
# 2     Microbiología            8       5.797101                   8
# 3  Biología General            1       0.724638                   1
# Asistencias por asignatura (Lectoescritura):
#                       Asignatura  Asistencias  % Asistencias  \
# 0                 Lectoescritura          250      48.449612
# 1                 Cat. Inducción           81      15.697674
# 2          Convivir y trascender           47       9.108527
# 3        Cultura De La Legalidad           24       4.651163
# 4                Química General           18       3.488372
# 5                Investigación I           12       2.325581
# 6                      Inglés II           10       1.937984
# 7          Hermenéutica Jurídica           10       1.937984
# 8               Morfoisiología I            9       1.744186
# 9                       Inglés I            9       1.744186
# 10              Biología General            8       1.550388
# 11  Epistemología Prim. Auxilios            7       1.356589
# 12              Gestión Cultural            6       1.162791
# 13        Fund.Psic. Fund. Admon            4       0.775194
# 14                    Bioquimica            4       0.775194
# 15              Psic.Ciclo Vital            3       0.581395
# 16           Cálculo Diferencial            3       0.581395
# 17            Sistema De Derecho            3       0.581395
# 18              Cálculo Integral            3       0.581395
# 19                    Inglés III            2       0.387597
# 20               F.Psicosociales            1       0.193798
# 21        Física (Fund.Mecánica)            1       0.193798
# 22                 Microbiología            1       0.193798
#
#     Asistencias reales
# 0                   82
# 1                   52
# 2                   24
# 3                   19
# 4                   18
# 5                    7
# 6                    6
# 7                    4
# 8                    9
# 9                    9
# 10                   7
# 11                   4
# 12                   3
# 13                   4
# 14                   4
# 15                   2
# 16                   3
# 17                   1
# 18                   1
# 19                   2
# 20                   1
# 21                   1
# 22                   1
# Asistencias por asignatura (Inglés):
#                             Asignatura  Asistencias  % Asistencias  \
# 0                            Inglés II          158      81.865285
# 1                           Inglés III           21      10.880829
# 2                             Inglés I           12       6.217617
# 3                       Lectoescritura            1       0.518135
# 4                            Inglés II            1       0.518135
#
#    Asistencias reales
# 0                  52
# 1                  16
# 2                   7
# 3                   1
# 4                   1

# %%
import pandas as pd
import matplotlib.pyplot as plt
import unicodedata
def limpiar_nombre(nombre):
    if isinstance(nombre, str):
        nombre = nombre.strip().title()  
        nombre = unicodedata.normalize("NFKC", nombre)
        return nombre
    return nombre  
for df in [df_lecto, df_mate, df_quimica, df_ingles]:
    df['Tutor'] = df['Tutor'].apply(limpiar_nombre)
def contar_asistencias(df):
    return df['Tutor'].value_counts()

conteo_df1 = contar_asistencias(df_lecto)
conteo_df2 = contar_asistencias(df_mate)
conteo_df3 = contar_asistencias(df_quimica)
conteo_df4 = contar_asistencias(df_ingles)
conteo_total = pd.concat([conteo_df1, conteo_df2, conteo_df3, conteo_df4], axis=1).fillna(0)
conteo_total['Total'] = conteo_total.sum(axis=1)
conteo_total = conteo_total.sort_values(by='Total', ascending=False)

plt.figure(figsize=(10, 6))
bars = plt.barh(conteo_total.index, conteo_total['Total'], color='skyblue')
plt.title('Conteo de Asistencias por Tutor')
plt.xlabel('Número de Asistencias')
plt.ylabel('Tutor')

for bar in bars:
    plt.text(bar.get_width(), bar.get_y() + bar.get_height()/2, f'{int(bar.get_width())}', 
             va='center', ha='left', color='black', fontweight='bold')
total_tutorias = conteo_total['Total'].sum()
plt.gca().text(0.95, 0.95, f'Total de Tutorías: {total_tutorias}', 
               transform=plt.gca().transAxes, ha='right', va='top', 
               fontsize=10, color='black', fontweight='bold')

plt.show()

# %%
##Analisis

import pandas as pd
import matplotlib.pyplot as plt

def distribucion_por_fecha(df):
    df['Fecha'] = pd.to_datetime(df['Fecha : Recordar (DD/MM/AAAA)'], format='%d/%m/%Y')
    df['Mes'] = df['Fecha'].dt.month
    asistencias_por_mes = df['Mes'].value_counts().sort_index()
    asistencias_por_semana = df['Semana académica'].value_counts().sort_index()
    asistencias_por_dia = df['Día de la semana'].value_counts().sort_index()
    return asistencias_por_mes, asistencias_por_semana, asistencias_por_dia
def distribucion_por_jornada(df):
    asistencias_por_jornada = df['Jornada'].value_counts().sort_index()
    jornada_mas_asistencias = asistencias_por_jornada.idxmax()
    return asistencias_por_jornada, jornada_mas_asistencias
def distribucion_por_programa(df):
    asistencias_por_programa = df['Programa curricular'].astype(str).value_counts().sort_index()
    return asistencias_por_programa
def distribucion_por_tutor(df):
    asistencias_por_tutor = df['Tutor'].value_counts().sort_index()
    return asistencias_por_tutor
def distribucion_por_asignatura(df):
    asistencias_por_asignatura = df['Asignatura'].value_counts().sort_index()
    return asistencias_por_asignatura
def motivos_de_consulta(df):
    motivos = df['Motivo de la consulta'].value_counts().sort_index()
    return motivos
def calcular_porcentajes(series):
    total = series.sum()
    porcentajes = (series / total) * 100
    return porcentajes
dataframes = {
    'lectoescritura': df_lecto,
    'matemáticas': df_mate,
    'química': df_quimica,
    'inglés': df_ingles
}
resultados = {
    'fecha': {},
    'jornada': {},
    'programa': {},
    'tutor': {},
    'asignatura': {},
    'motivos': {},
    'programas_especiales': {}
}
for area, df in dataframes.items():
    asistencias_por_mes, asistencias_por_semana, asistencias_por_dia = distribucion_por_fecha(df)
    resultados['fecha'][area] = {
        'mes': asistencias_por_mes,
        'semana': asistencias_por_semana,
        'dia': asistencias_por_dia
    }
    asistencias_por_jornada, jornada_mas_asistencias = distribucion_por_jornada(df)
    resultados['jornada'][area] = {
        'asistencias': asistencias_por_jornada,
        'jornada_mas_asistencias': jornada_mas_asistencias
    }
    asistencias_por_programa = distribucion_por_programa(df)
    resultados['programa'][area] = asistencias_por_programa
    asistencias_por_tutor = distribucion_por_tutor(df)
    resultados['tutor'][area] = asistencias_por_tutor
    asistencias_por_asignatura = distribucion_por_asignatura(df)
    resultados['asignatura'][area] = asistencias_por_asignatura
    motivos = motivos_de_consulta(df)
    resultados['motivos'][area] = motivos
for area, data in resultados['fecha'].items():
    porcentaje_dia = calcular_porcentajes(data['dia'])
    print(f"Porcentaje de asistencias por día de la semana en {area}:\n", porcentaje_dia)
for area, data in resultados['motivos'].items():
    porcentaje_motivos = calcular_porcentajes(data)
    print(f"Porcentaje de motivos de consulta en {area}:\n", porcentaje_motivos)
for area, data in resultados['jornada'].items():
    print(f"Asistencias por jornada en {area}:\n", data['asistencias'])
    print(f"Jornada con más asistencias en {area}: {data['jornada_mas_asistencias']}")
for area, data in resultados['programa'].items():
    print(f"Asistencias por programa curricular en {area}:\n", data)
for area, data in resultados['tutor'].items():
    print(f"Asistencias por tutor en {area}:\n", data)
for area, data in resultados['asignatura'].items():
    print(f"Asistencias por asignatura en {area}:\n", data)
# Out:
# Porcentaje de asistencias por día de la semana en lectoescritura:
#  Día de la semana
# jueves       12.790698
# lunes        21.705426
# martes       23.449612
# miércoles    21.124031
# sábado        0.387597
# viernes      20.542636
# Name: count, dtype: float64
# Porcentaje de asistencias por día de la semana en matemáticas:
#  Día de la semana
# jueves       24.418605
# lunes        13.081395
# martes       21.947674
# miércoles    23.837209
# sábado        0.290698
# viernes      16.424419
# Name: count, dtype: float64
# Porcentaje de asistencias por día de la semana en química:
#  Día de la semana
# jueves       10.144928
# lunes        10.869565
# martes       28.260870
# miércoles    27.536232
# viernes      23.188406
# Name: count, dtype: float64
# Porcentaje de asistencias por día de la semana en inglés:
#  Día de la semana
# jueves       23.316062
# lunes        13.471503
# martes       19.689119
# miércoles    22.797927
# sábado        1.036269
# viernes      19.689119
# Name: count, dtype: float64
# Porcentaje de motivos de consulta en lectoescritura:
#  Motivo de la consulta
# Estudiar para un examen              3.100775
# Estudiar para una entrega           85.077519
# Estudiar para una entrega            1.356589
# Estudio autónomo                     6.395349
# Reforzar temas vistos en clase       0.775194
# Revisar un ejercicio del taller      3.294574
# Name: count, dtype: float64
# Porcentaje de motivos de consulta en matemáticas:
#  Motivo de la consulta
# Estudiar para un examen             17.416546
# Estudiar para una entrega           21.915820
# Estudio autónomo                    22.060958
# Refonzan temas vistos en clase       0.145138
# Reforzar temas vistos en clase       5.660377
# Revisar un ejercicio del taller     32.801161
# Name: count, dtype: float64
# Porcentaje de motivos de consulta en química:
#  Motivo de la consulta
# Estudiar para un examen              3.623188
# Estudiar para una entrega           33.333333
# Estudio autónomo                    19.565217
# Reforzar temas vistos en clase      10.869565
# Revisar un ejercicio del taller     32.608696
# Name: count, dtype: float64
# Porcentaje de motivos de consulta en inglés:
#  Motivo de la consulta
# Estudiar para un examen           33.678756
# Estudiar para una entrega         60.621762
# Estudio autónomo                   4.663212
# Reforzar temas vistos en clase     1.036269
# Name: count, dtype: float64
# Asistencias por jornada en lectoescritura:
#  Jornada
# Mañana    407
# Tarde     109
# Name: count, dtype: int64
# Jornada con más asistencias en lectoescritura: Mañana
# Asistencias por jornada en matemáticas:
#  Jornada
# Mañana    520
# Tarde     169
# Name: count, dtype: int64
# Jornada con más asistencias en matemáticas: Mañana
# Asistencias por jornada en química:
#  Jornada
# Mañana    112
# Tarde      26
# Name: count, dtype: int64
# Jornada con más asistencias en química: Mañana
# Asistencias por jornada en inglés:
#  Jornada
# Mañana    179
# Tarde      15
# Name: count, dtype: int64
# Jornada con más asistencias en inglés: Mañana
# Asistencias por programa curricular en lectoescritura:
#  Programa curricular
# Administración de empresas               4
# Administración de empresas (d)           1
# Administración de empresas PAET         25
# Antropología                            11
# Arquitectura                            11
# Artes plásticas                          8
# Biología                                 3
# Contaduría pública                       2
# Derecho                                 20
# Derecho PAET                            62
# Diseño gráfico                          12
# Diseño industrial                       34
# Economía                                 2
# Enfermería                              33
# Enfermería PAET                         93
# Farmacia                                 2
# Filología e idiomas inglés              17
# Geología                                 2
# Gestión cultural y comunicativa PAET    15
# Ingeniería agroindustrial                1
# Ingeniería agronómica                   12
# Ingeniería agrícola                      5
# Ingeniería ambiental                    66
# Ingeniería civil                        26
# Ingeniería de petróleos                  4
# Ingeniería de sistemas e informática     1
# Ingeniería de sistemas y computación     1
# Ingeniería eléctrica                     2
# Ingeniería geológica                     1
# Ingeniería industrial                    2
# Ingeniería mecatrónica                   2
# Ingeniería mecánica                      1
# Ingeniería química                      11
# Medicina                                 2
# Medicina veterinaria                     5
# Nutrición y dietética                    5
# Odontología                              7
# Psicología                               2
# Química                                  3
# Name: count, dtype: int64
# Asistencias por programa curricular en matemáticas:
#  Programa curricular
# Administración de empresas                  17
# Administración de empresas (d)              25
# Administración de empresas PAET             19
# Administración de sistemas informáticos      7
# Biología                                    11
# Contaduría pública                           9
# Diseño industrial                            1
# Economía                                    18
# Enfermería                                  11
# Enfermería PAET                            121
# Farmacia                                    12
# Geología                                     5
# Gestión cultural y comunicativa PAET        21
# Ingeniería administrativa                    1
# Ingeniería agroindustrial                   14
# Ingeniería agronómica                       26
# Ingeniería agrícola                         12
# Ingeniería ambiental                        54
# Ingeniería civil                            22
# Ingeniería de petróleos                      7
# Ingeniería de sistemas e informática         4
# Ingeniería electrónica                      11
# Ingeniería eléctrica                        25
# Ingeniería física                            2
# Ingeniería geológica                         4
# Ingeniería industrial                       43
# Ingeniería mecatrónica                      37
# Ingeniería mecánica                         30
# Ingeniería química                          45
# Matemáticas                                 15
# Medicina veterinaria                        17
# Nutrición y dietética                       16
# Odontología                                  6
# Química                                      4
# Zootecnia                                   17
# Name: count, dtype: int64
# Asistencias por programa curricular en química:
#  Programa curricular
# Administración de empresas     3
# Biología                       7
# Enfermería PAET               80
# Geología                       5
# Ingeniería agroindustrial      1
# Ingeniería agronómica         13
# Ingeniería agrícola            2
# Ingeniería ambiental           2
# Ingeniería biológica           1
# Ingeniería civil               5
# Ingeniería mecatrónica         8
# Ingeniería mecánica            5
# Ingeniería química             3
# Medicina veterinaria           2
# Química                        1
# Name: count, dtype: int64
# Asistencias por programa curricular en inglés:
#  Programa curricular
# 0                                  1
# Administración de empresas         8
# Administración de empresas (d)     9
# Antropología                       1
# Biología                          16
# Contaduría pública                 1
# Derecho                            1
# Derecho PAET                       1
# Diseño gráfico                     5
# Economía                           2
# Enfermería PAET                    1
# Filología e idiomas inglés         3
# Geología                           2
# Ingeniería administrativa          3
# Ingeniería agroindustrial         12
# Ingeniería agronómica             20
# Ingeniería agrícola                9
# Ingeniería ambiental               9
# Ingeniería civil                  10
# Ingeniería industrial             10
# Ingeniería mecatrónica             3
# Ingeniería química                12
# Matemáticas                       25
# Medicina veterinaria              10
# Nutrición y dietética              9
# Psicología                         6
# Trabajo social                     2
# Zootecnia                          3
# Name: count, dtype: int64
# Asistencias por tutor en lectoescritura:
#  Tutor
# Daniel Corredor     138
# Harvey Castro       116
# Juliana Varona      147
# Nicolás Martínez    115
# Name: count, dtype: int64
# Asistencias por tutor en matemáticas:
#  Tutor
# Andrés Ramírez        185
# Armando Sinisterra     26
# Camilo Realpe          16
# Cristian Fajardo      284
# Janeth Pinzón         178
# Name: count, dtype: int64
# Asistencias por tutor en química:
#  Tutor
# Armando Sinisterra    135
# Camilo Realpe           3
# Name: count, dtype: int64
# Asistencias por tutor en inglés:
#  Tutor
# Juan David Grueso    68
# Luis Aguiño          81
# Luisana Paez         45
# Name: count, dtype: int64
# Asistencias por asignatura en lectoescritura:
#  Asignatura
# Biología General                  8
# Bioquimica                        4
# Cat. Inducción                   81
# Convivir y trascender            47
# Cultura De La Legalidad          24
# Cálculo Diferencial               3
# Cálculo Integral                  3
# Epistemología Prim. Auxilios      7
# F.Psicosociales                   1
# Fund.Psic. Fund. Admon            4
# Física (Fund.Mecánica)            1
# Gestión Cultural                  6
# Hermenéutica Jurídica            10
# Inglés I                          9
# Inglés II                        10
# Inglés III                        2
# Investigación I                  12
# Lectoescritura                  250
# Microbiología                     1
# Morfoisiología I                  9
# Psic.Ciclo Vital                  3
# Química General                  18
# Sistema De Derecho                3
# Name: count, dtype: int64
# Asistencias por asignatura en matemáticas:
#  Asignatura
# Cálculo Diferencial                118
# Cálculo Integral                    73
# Física (Fund.Mecánica)               8
# Geometría Vectorial y analítica      9
# Matemáticas                        407
# Programacion de computadores        36
# Álgebra lineal                      38
# Name: count, dtype: int64
# Asistencias por asignatura en química:
#  Asignatura
# Biología General     1
# Bioquímica          34
# Microbiología        8
# Química General     95
# Name: count, dtype: int64
# Asistencias por asignatura en inglés:
#  Asignatura
#                           Inglés II      1
# Inglés I                                12
# Inglés II                              158
# Inglés III                              21
# Lectoescritura                           1
# Name: count, dtype: int64
